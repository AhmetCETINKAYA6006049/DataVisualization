# %%
import numpy as np
import pandas as pd

# %%
covid_data = pd.read_csv('owid-covid-data.csv')

# %%
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %% [markdown]
# https://www.listendata.com/2019/07/how-to-filter-pandas-dataframe.html

# %% [markdown]
# filter only the countries we want

# %%
turkey_covid_data = covid_data[covid_data.location == "Turkey"]
turkey_covid_data.head(5)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 96487      TUR      Asia   Turkey  2020-03-11          1.0        1.0
# 96488      TUR      Asia   Turkey  2020-03-12          1.0        0.0
# 96489      TUR      Asia   Turkey  2020-03-13          5.0        4.0
# 96490      TUR      Asia   Turkey  2020-03-14          5.0        0.0
# 96491      TUR      Asia   Turkey  2020-03-15          6.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 96487                 NaN           NaN         NaN                  NaN  ...
# 96488                 NaN           NaN         NaN                  NaN  ...
# 96489                 NaN           NaN         NaN                  NaN  ...
# 96490                 NaN           NaN         NaN                  NaN  ...
# 96491                 NaN           NaN         NaN                  NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %% [markdown]
# https://realpython.com/pandas-sort-python/#getting-familiar-with-sort_index

# %%
turkey_covid_data.sort_values("date")
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 96487      TUR      Asia   Turkey  2020-03-11          1.0        1.0
# 96488      TUR      Asia   Turkey  2020-03-12          1.0        0.0
# 96489      TUR      Asia   Turkey  2020-03-13          5.0        4.0
# 96490      TUR      Asia   Turkey  2020-03-14          5.0        0.0
# 96491      TUR      Asia   Turkey  2020-03-15          6.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 96983      TUR      Asia   Turkey  2021-07-20    5546166.0     8780.0
# 96984      TUR      Asia   Turkey  2021-07-21    5554317.0     8151.0
# 96985      TUR      Asia   Turkey  2021-07-22    5563903.0     9586.0
# 96986      TUR      Asia   Turkey  2021-07-23    5574997.0    11094.0
# 96987      TUR      Asia   Turkey  2021-07-24    5587378.0    12381.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# show daily statistics in Turkey  last 15 days

# %%
last_15_days_covid = turkey_covid_data[turkey_covid_data.date > '2021-07-10']
last_15_days_covid.head(15)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 96974      TUR      Asia   Turkey  2021-07-11    5481555.0     5261.0
# 96975      TUR      Asia   Turkey  2021-07-12    5486959.0     5404.0
# 96976      TUR      Asia   Turkey  2021-07-13    5493244.0     6285.0
# 96977      TUR      Asia   Turkey  2021-07-14    5500151.0     6907.0
# 96978      TUR      Asia   Turkey  2021-07-15    5507455.0     7304.0
# 96979      TUR      Asia   Turkey  2021-07-16    5514373.0     6918.0
# 96980      TUR      Asia   Turkey  2021-07-17    5522039.0     7666.0
# 96981      TUR      Asia   Turkey  2021-07-18    5522039.0        0.0
# 96982      TUR      Asia   Turkey  2021-07-19    5537386.0    15347.0
# 96983      TUR      Asia   Turkey  2021-07-20    5546166.0     8780.0
# 96984      TUR      Asia   Turkey  2021-07-21    5554317.0     8151.0
# 96985      TUR      Asia   Turkey  2021-07-22    5563903.0     9586.0
# ...

# %% [markdown]
# plot daily cases as barplot
# https://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot

# %%
last_15_days_covid.plot(kind = "bar", x= "date", y = "new_cases")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# plot total deaths and new deaths last 15 days as line plot

# %%
import matplotlib.pyplot as plt
ax = plt.gca()
last_15_days_covid.plot(kind = "line", x= "date", y = "total_deaths", ax = ax, xlabel = "date", ylabel ="count")
last_15_days_covid.plot(kind = "line", x= "date", y = "new_deaths", color = 'red', ax = ax, xlabel = "date", ylabel ="count" )
plt.yscale("log")
plt.xticks(rotation = 90)
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(-2.0, 0, '2021-07-23'),
#   Text(0.0, 0, '2021-07-11'),
#   Text(2.0, 0, '2021-07-13'),
#   Text(4.0, 0, '2021-07-15'),
#   Text(6.0, 0, '2021-07-17'),
#   Text(8.0, 0, '2021-07-19'),
#   Text(10.0, 0, '2021-07-21'),
#   Text(12.0, 0, '2021-07-23'),
#   Text(14.0, 0, '')])
